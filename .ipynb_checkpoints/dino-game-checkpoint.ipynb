# %%
# install pytorch
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116
# show what we got
# !pip list
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# Requirement already satisfied: torch in c:\users\renny\anaconda3\lib\site-packages (1.13.1+cu116)
# Requirement already satisfied: torchvision in c:\users\renny\anaconda3\lib\site-packages (0.14.1+cu116)
# Requirement already satisfied: torchaudio in c:\users\renny\anaconda3\lib\site-packages (0.13.1+cu116)
# Requirement already satisfied: typing-extensions in c:\users\renny\anaconda3\lib\site-packages (from torch) (4.1.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\renny\anaconda3\lib\site-packages (from torchvision) (9.0.1)
# Requirement already satisfied: requests in c:\users\renny\anaconda3\lib\site-packages (from torchvision) (2.27.1)
# Requirement already satisfied: numpy in c:\users\renny\anaconda3\lib\site-packages (from torchvision) (1.21.5)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\renny\anaconda3\lib\site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\renny\anaconda3\lib\site-packages (from requests->torchvision) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\renny\anaconda3\lib\site-packages (from requests->torchvision) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\renny\anaconda3\lib\site-packages (from requests->torchvision) (3.3)
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.4.0
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# ale-py                        0.7.4
# anaconda-client               1.9.0
# anaconda-navigator            2.1.4
# anaconda-project              0.10.2
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# AutoROM                       0.4.2
# AutoROM.accept-rom-license    0.5.5
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# binaryornot                   0.4.4
# bitarray                      2.4.1
# bkcharts                      0.2
# black                         19.10b0
# bleach                        4.1.0
# bokeh                         2.4.2
# boto3                         1.21.32
# botocore                      1.24.32
# Bottleneck                    1.3.4
# brotlipy                      0.7.0
# cachetools                    4.2.2
# certifi                       2021.10.8
# cffi                          1.15.0
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.0.4
# cloudpickle                   2.0.0
# clyent                        1.2.2
# colorama                      0.4.4
# colorcet                      2.0.6
# comtypes                      1.1.10
# conda                         4.12.0
# conda-build                   3.21.8
# conda-content-trust           0+unknown
# conda-pack                    0.6.0
# conda-package-handling        1.8.1
# conda-repo-cli                1.0.4
# conda-token                   0.3.0
# conda-verify                  3.4.2
# constantly                    15.1.0
# cookiecutter                  1.7.3
# cryptography                  3.4.8
# cssselect                     1.1.0
# cycler                        0.11.0
# Cython                        0.29.28
# cytoolz                       0.11.0
# daal4py                       2021.5.0
# dask                          2022.2.1
# datashader                    0.13.0
# datashape                     0.5.4
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# diff-match-patch              20200713
# distributed                   2022.2.1
# docutils                      0.17.1
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# executing                     0.8.3
# fastjsonschema                2.15.1
# filelock                      3.6.0
# flake8                        3.9.2
# Flask                         1.1.2
# fonttools                     4.25.0
# frozenlist                    1.2.0
# fsspec                        2022.2.0
# future                        0.18.2
# gensim                        4.1.2
# glob2                         0.7
# google-api-core               1.25.1
# google-auth                   1.33.0
# google-auth-oauthlib          0.4.6
# google-cloud-core             1.7.1
# google-cloud-storage          1.31.0
# google-crc32c                 1.1.2
# google-resumable-media        1.3.1
# googleapis-common-protos      1.53.0
# greenlet                      1.1.1
# grpcio                        1.51.3
# gym                           0.21.0
# h5py                          3.6.0
# HeapDict                      1.0.1
# holoviews                     1.14.8
# hvplot                        0.7.3
# hyperlink                     21.0.0
# idna                          3.3
# imagecodecs                   2021.8.26
# imageio                       2.9.0
# imagesize                     1.3.0
# importlib-metadata            4.13.0
# importlib-resources           5.12.0
# incremental                   21.3.0
# inflection                    0.5.1
# iniconfig                     1.1.1
# intake                        0.6.5
# intervaltree                  3.1.0
# ipykernel                     6.9.1
# ipython                       8.2.0
# ipython-genutils              0.2.0
# ipywidgets                    7.6.5
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# itsdangerous                  2.0.1
# jdcal                         1.4.1
# jedi                          0.18.1
# Jinja2                        2.11.3
# jinja2-time                   0.2.0
# jmespath                      0.10.0
# joblib                        1.1.0
# json5                         0.9.6
# jsonschema                    4.4.0
# jupyter                       1.0.0
# jupyter-client                6.1.12
# jupyter-console               6.4.0
# jupyter-core                  4.9.2
# jupyter-server                1.13.5
# jupyterlab                    3.3.2
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.10.3
# jupyterlab-widgets            1.0.0
# jupyterthemes                 0.20.0
# keyring                       23.4.0
# kiwisolver                    1.3.2
# lazy-object-proxy             1.6.0
# lesscpy                       0.15.1
# libarchive-c                  2.9
# libtorrent                    2.0.7
# llvmlite                      0.38.0
# locket                        0.2.1
# lxml                          4.8.0
# Markdown                      3.3.4
# markdown-it-py                2.2.0
# MarkupSafe                    2.0.1
# matplotlib                    3.5.1
# matplotlib-inline             0.1.2
# mccabe                        0.6.1
# mdurl                         0.1.2
# menuinst                      1.4.18
# mistune                       0.8.4
# mkl-fft                       1.3.1
# mkl-random                    1.2.2
# mkl-service                   2.4.0
# mock                          4.0.3
# mpmath                        1.2.1
# msgpack                       1.0.2
# mss                           7.0.1
# multidict                     5.1.0
# multipledispatch              0.6.0
# munkres                       1.1.4
# mypy-extensions               0.4.3
# navigator-updater             0.2.1
# nbclassic                     0.3.5
# nbclient                      0.5.13
# nbconvert                     6.4.4
# nbformat                      5.3.0
# nest-asyncio                  1.5.5
# networkx                      2.7.1
# nltk                          3.7
# nose                          1.3.7
# notebook                      6.4.8
# numba                         0.55.1
# numexpr                       2.8.1
# numpy                         1.21.5
# numpydoc                      1.2
# oauthlib                      3.2.2
# olefile                       0.46
# opencv-python                 4.7.0.72
# openpyxl                      3.0.9
# packaging                     21.3
# pandas                        1.4.2
# pandocfilters                 1.5.0
# panel                         0.13.0
# param                         1.12.0
# paramiko                      2.8.1
# parsel                        1.6.0
# parso                         0.8.3
# partd                         1.2.0
# pathspec                      0.7.0
# patsy                         0.5.2
# pep8                          1.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.0.1
# pip                           21.2.4
# pkginfo                       1.8.2
# plotly                        5.6.0
# pluggy                        1.0.0
# ply                           3.11
# poyo                          0.5.0
# prometheus-client             0.13.1
# prompt-toolkit                3.0.20
# Protego                       0.1.16
# protobuf                      3.20.3
# psutil                        5.8.0
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py                            1.11.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycodestyle                   2.7.0
# pycosat                       0.6.3
# pycparser                     2.21
# pyct                          0.4.6
# pycurl                        7.44.1
# PyDirectInput                 1.0.4
# PyDispatcher                  2.0.5
# pydocstyle                    6.1.1
# pyerfa                        2.0.0
# pyflakes                      2.3.1
# Pygments                      2.14.0
# PyHamcrest                    2.0.2
# PyJWT                         2.1.0
# pylint                        2.9.6
# pyls-spyder                   0.4.0
# PyNaCl                        1.4.0
# pyodbc                        4.0.32
# pyOpenSSL                     21.0.0
# pyparsing                     3.0.4
# pyreadline                    2.1
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# pytesseract                   0.3.10
# pytest                        7.1.1
# python-dateutil               2.8.2
# python-lsp-black              1.0.0
# python-lsp-jsonrpc            1.0.0
# python-lsp-server             1.2.4
# python-slugify                5.0.2
# python-snappy                 0.6.0
# pytz                          2021.3
# pyviz-comms                   2.0.2
# PyWavelets                    1.3.0
# pywin32                       302
# pywin32-ctypes                0.2.0
# pywinpty                      2.0.2
# PyYAML                        6.0
# pyzmq                         22.3.0
# QDarkStyle                    3.0.2
# qstylizer                     0.1.10
# QtAwesome                     1.0.3
# qtconsole                     5.3.0
# QtPy                          2.0.1
# queuelib                      1.5.0
# regex                         2022.3.15
# requests                      2.27.1
# requests-file                 1.5.1
# requests-oauthlib             1.3.1
# rich                          13.3.1
# rope                          0.22.0
# rsa                           4.7.2
# Rtree                         0.9.7
# ruamel-yaml-conda             0.15.100
# s3transfer                    0.5.0
# scikit-image                  0.19.2
# scikit-learn                  1.0.2
# scikit-learn-intelex          2021.20220215.102710
# scipy                         1.7.3
# Scrapy                        2.6.1
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# service-identity              18.1.0
# setuptools                    61.2.0
# sip                           4.19.13
# six                           1.16.0
# smart-open                    5.1.0
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# sortedcollections             2.1.0
# sortedcontainers              2.4.0
# soupsieve                     2.3.1
# Sphinx                        4.4.0
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        5.1.5
# spyder-kernels                2.1.3
# SQLAlchemy                    1.4.32
# stable-baselines3             1.7.0
# stack-data                    0.2.0
# statsmodels                   0.13.2
# sympy                         1.10.1
# tables                        3.6.1
# tabulate                      0.8.9
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.0.1
# tensorboard                   2.12.0
# tensorboard-data-server       0.7.0
# tensorboard-plugin-wit        1.8.1
# terminado                     0.13.1
# testpath                      0.5.0
# text-unidecode                1.3
# textdistance                  4.2.1
# threadpoolctl                 2.2.0
# three-merge                   0.1.1
# tifffile                      2021.7.2
# tinycss                       0.4
# tldextract                    3.2.0
# toml                          0.10.2
# tomli                         1.2.2
# toolz                         0.11.2
# torch                         1.13.1+cu116
# torchaudio                    0.13.1+cu116
# torchvision                   0.14.1+cu116
# tornado                       6.1
# tqdm                          4.64.0
# traitlets                     5.1.1
# Twisted                       22.2.0
# twisted-iocpsupport           1.0.2
# typed-ast                     1.4.3
# typing_extensions             4.1.1
# ujson                         5.1.0
# Unidecode                     1.2.0
# urllib3                       1.26.9
# w3lib                         1.21.0
# watchdog                      2.1.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.58.0
# Werkzeug                      2.0.3
# wheel                         0.37.1
# widgetsnbextension            3.5.2
# win-inet-pton                 1.1.0
# win-unicode-console           0.5
# wincertstore                  0.2
# wrapt                         1.12.1
# xarray                        0.20.1
# xlrd                          2.0.1
# XlsxWriter                    3.0.3
# xlwings                       0.24.9
# yapf                          0.31.0
# yarl                          1.6.3
# zict                          2.0.0
# zipp                          3.7.0
# zope.interface                5.4.0

# %%
# install stable-baslines (implementations of reinforcement learning algorithms in PyTorch)
# !pip install stable-baselines3[extra] protobuf==3.20.*
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\renny\anaconda3\lib\site-packages (1.7.0)
# Requirement already satisfied: protobuf==3.20.* in c:\users\renny\anaconda3\lib\site-packages (3.20.3)
# Requirement already satisfied: torch>=1.11 in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.13.1+cu116)
# Requirement already satisfied: cloudpickle in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: matplotlib in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: numpy in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.21.5)
# Requirement already satisfied: importlib-metadata~=4.13 in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.13.0)
# Requirement already satisfied: gym==0.21 in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: pandas in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.4.2)
# Requirement already satisfied: rich in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (13.3.1)
# Requirement already satisfied: pillow in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (9.0.1)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: ale-py==0.7.4 in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.7.4)
# Requirement already satisfied: opencv-python in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.7.0.72)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.12.0)
# Requirement already satisfied: tqdm in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.64.0)
# Requirement already satisfied: psutil in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (5.8.0)
# Requirement already satisfied: importlib-resources in c:\users\renny\anaconda3\lib\site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (5.12.0)
# Requirement already satisfied: click in c:\users\renny\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (8.0.4)
# Requirement already satisfied: requests in c:\users\renny\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.27.1)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\renny\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.5.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\renny\anaconda3\lib\site-packages (from importlib-metadata~=4.13->stable-baselines3[extra]) (3.7.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (61.2.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.0.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.33.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.3.4)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.51.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\renny\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\renny\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\renny\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.2.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\renny\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\renny\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\renny\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\renny\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\renny\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\renny\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\renny\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\renny\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)
# Requirement already satisfied: typing-extensions in c:\users\renny\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (4.1.1)
# Requirement already satisfied: libtorrent in c:\users\renny\anaconda3\lib\site-packages (from AutoROM.accept-rom-license->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.0.7)
# Requirement already satisfied: colorama in c:\users\renny\anaconda3\lib\site-packages (from click->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\renny\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\renny\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\renny\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\renny\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\renny\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\renny\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\renny\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2021.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.1.0 in c:\users\renny\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.14.0 in c:\users\renny\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\renny\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.1.0->rich->stable-baselines3[extra]) (0.1.2)

# %%
# install pydirectinput for input handaling
# !pip install pydirectinput
# Out:
# Requirement already satisfied: pydirectinput in c:\users\renny\anaconda3\lib\site-packages (1.0.4)

# %%
# install pytesseract for OCR
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in c:\users\renny\anaconda3\lib\site-packages (0.3.10)
# Requirement already satisfied: packaging>=21.3 in c:\users\renny\anaconda3\lib\site-packages (from pytesseract) (21.3)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\renny\anaconda3\lib\site-packages (from pytesseract) (9.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\renny\anaconda3\lib\site-packages (from packaging>=21.3->pytesseract) (3.0.4)

# %%
# instal mss for image capture
# !pip install mss
# Out:
# Requirement already satisfied: mss in c:\users\renny\anaconda3\lib\site-packages (7.0.1)

# %%
# file path
import os
# screen capture
from mss import mss
# command sending 
import pydirectinput
# fram proccesing
import cv2
# transformatinoal framework
import numpy as np
# OCR for game extraction
import pytesseract
# visualize captures
from matplotlib import pyplot as plt
# pause time
import time
# env componenet
from gym import Env
# box for the image, descrete for possible actions
from gym.spaces import Box, Discrete
# saving models
from stable_baselines3.common.callbacks import BaseCallback
# check env
from stable_baselines3.common import env_checker
# get DQN algorithm
from stable_baselines3 import DQN

# %%
 # set tessoract locations
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
class game(Env):
    # set env action and obser shaps
    def __init__(self):
        # use the base class
        super().__init__()
        # setup spaces
        self.observation_space = Box(low=0, high=255, shape=(1,83,100), dtype=np.uint8)
        self.action_space = Discrete(3)
        # def extraction parameters
        self.cap = mss()
        self.game_location = {'top':300, 'left':500, 'width':400, 'height':400}
        self.done_location = {'top':405, 'left':800, 'width':330, 'height':80}
        
    # called to do somehitng in the game     
    def step(self, action):
        # actions: 0 - space(jump), 1 - down(duck), 2 - no action(no op) 
        action_map = {0: 'space', 1: 'down', 2: 'no_op'}
    
        # simulate press if not no_op
        if action != 2:
            pydirectinput.press(action_map[action])
    
        # check for gameover
        done, done_cap = self.get_done()
        # check next observ
        new_observ = self.get_observation()
        # reward - get point for each frame that isn't gameover
        reward = 1
        #info dic
        info = {}
        return new_observ, reward, done, info 
    # vusualize the game
    def render(self):
        cv2.imshow('Game', np.array(self.cap.grab(self.game_location))[:,:,:3])
        if cv2.waitKey(1) & 0xFF == ord('q'):
            self.close()
    # closes the done observ
    def close(self):
        cv2.destroyAllWindows()
    # restart the game     
    def reset(self):
        time.sleep(1)
        pydirectinput.press('up')
        pydirectinput.click(x=150, y=150)
        pydirectinput.press('space')
        time.sleep(2)
        return self.get_observation()

    # get a part of the observation that we want
    def get_observation(self):
        # get screen capture (only first 3 cahnnels) and extract the values from it
        raw = np.array(self.cap.grab(self.game_location))[:,:,:3]
        # grayscale
        gray = cv2.cvtColor(raw, cv2.COLOR_BGR2GRAY)
        # resize
        resized = cv2.resize(gray, (100,83))
        # add channels first 
        channel = np.reshape(resized, (1, 83, 100))
        return channel
    # get the done text with OCR
    def get_done(self):
        # get done screen
        done_cap = np.array(self.cap.grab(self.done_location))[:,:,:3]
        # valid done text
        done_str = ['GAME','GAHE']
        
        # Apply OCR
        # flag to recognize gameover
        done = False
        # get string
        res = pytesseract.image_to_string(done_cap)[:4]
        if res in done_str:
            # found gameover
            done = True
        # return game status
        return done, done_cap

# %%
env = game()

# %%
done, done_cap = env.get_done()

# %%
done
# Out:
# False

# %%
env.render()

# %%
env.close()

# %%
# observ values
env.get_observation()
# Out:
# array([[[61, 61, 61, ..., 61, 61, 61],
#         [61, 61, 61, ..., 61, 61, 61],
#         [61, 61, 61, ..., 61, 61, 61],
#         ...,
#         [61, 61, 61, ..., 61, 61, 61],
#         [61, 61, 61, ..., 61, 61, 61],
#         [61, 61, 61, ..., 61, 61, 61]]], dtype=uint8)

# %%
# observ after proccecing
plt.imshow(env.get_observation()[0])

# %%
# observ after proccecing it back to the original
plt.imshow(cv2.cvtColor(env.get_observ()[0], cv2.COLOR_BGR2RGB))

# %%
# play 10 games
for ep in range(5):
    obs = env.reset()
    done = False
    total_reward = 0
    
    while not done:
        obs, reward, done, info = env.step(env.action_space.sample())
        total_reward += reward
    print(f'total reward for ep {ep} is {total_reward}')
# Out:
# total reward for ep 0 is 10
# total reward for ep 1 is 9
# total reward for ep 2 is 7
# total reward for ep 3 is 7
# total reward for ep 4 is 7

# %%
# check that env is ok
env_checker.check_env(env)

# %%
# def callbacks for saving models
class TrainAndLoggingCallback(BaseCallback):
    
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path
        
    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)
            
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

# %%
# set DIRs
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
# set our call back
callback = TrainAndLoggingCallback(check_freq=300, save_path=CHECKPOINT_DIR)

# %%
# create DQN model
model = DQN('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1,
            buffer_size= 150000, learning_starts= 100)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# training
model.learn(total_timesteps=1000, callback=callback)
# Out:
# Logging to ./logs/DQN_5
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.75     |
# |    ep_rew_mean      | 6.75     |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1        |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 27       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.62     |
# |    ep_rew_mean      | 8.62     |
# |    exploration_rate | 0.345    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1        |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 69       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.92     |
# |    ep_rew_mean      | 9.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2        |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 119      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.347    |
# |    n_updates        | 4        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.69     |
# |    ep_rew_mean      | 7.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1        |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 123      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.296    |
# |    n_updates        | 5        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.4      |
# |    ep_rew_mean      | 9.4      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2        |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 188      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00656  |
# |    n_updates        | 21       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8        |
# |    ep_rew_mean      | 8        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2        |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 192      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0091   |
# |    n_updates        | 22       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8        |
# |    ep_rew_mean      | 8        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1        |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 224      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00484  |
# |    n_updates        | 30       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.34     |
# |    ep_rew_mean      | 9.34     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 2        |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 299      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000634 |
# |    n_updates        | 49       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.17     |
# |    ep_rew_mean      | 9.17     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1        |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 330      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000463 |
# |    n_updates        | 57       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.53     |
# |    ep_rew_mean      | 9.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2        |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 381      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00014  |
# |    n_updates        | 70       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.75     |
# |    ep_rew_mean      | 8.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1        |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 385      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.66e-05 |
# |    n_updates        | 71       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.65     |
# |    ep_rew_mean      | 8.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1        |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 415      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.86e-05 |
# |    n_updates        | 78       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.85     |
# |    ep_rew_mean      | 9.85     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 2        |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 512      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.87e-05 |
# |    n_updates        | 102      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.21     |
# |    ep_rew_mean      | 9.21     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2        |
# |    time_elapsed     | 255      |
# |    total_timesteps  | 516      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.72e-05 |
# |    n_updates        | 103      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.67     |
# |    ep_rew_mean      | 8.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1        |
# |    time_elapsed     | 261      |
# |    total_timesteps  | 520      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.35e-05 |
# |    n_updates        | 104      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19     |
# |    ep_rew_mean      | 8.19     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1        |
# |    time_elapsed     | 268      |
# |    total_timesteps  | 524      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.22e-05 |
# |    n_updates        | 105      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.76     |
# |    ep_rew_mean      | 7.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1        |
# |    time_elapsed     | 274      |
# |    total_timesteps  | 528      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.96e-05 |
# |    n_updates        | 106      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.39     |
# |    ep_rew_mean      | 7.39     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1        |
# |    time_elapsed     | 280      |
# |    total_timesteps  | 532      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00862  |
# |    n_updates        | 107      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.26     |
# |    ep_rew_mean      | 7.26     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1        |
# |    time_elapsed     | 290      |
# |    total_timesteps  | 552      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.96e-05 |
# |    n_updates        | 112      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.95     |
# |    ep_rew_mean      | 6.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1        |
# |    time_elapsed     | 296      |
# |    total_timesteps  | 556      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00337  |
# |    n_updates        | 113      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.89     |
# |    ep_rew_mean      | 6.89     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1        |
# |    time_elapsed     | 311      |
# |    total_timesteps  | 579      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.8e-05  |
# |    n_updates        | 119      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.62     |
# |    ep_rew_mean      | 6.62     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1        |
# |    time_elapsed     | 317      |
# |    total_timesteps  | 583      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00493  |
# |    n_updates        | 120      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.9      |
# |    ep_rew_mean      | 6.9      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1        |
# |    time_elapsed     | 344      |
# |    total_timesteps  | 635      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00857  |
# |    n_updates        | 133      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.66     |
# |    ep_rew_mean      | 6.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1        |
# |    time_elapsed     | 350      |
# |    total_timesteps  | 639      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.12e-05 |
# |    n_updates        | 134      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.51     |
# |    ep_rew_mean      | 6.51     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1        |
# |    time_elapsed     | 360      |
# |    total_timesteps  | 651      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.5e-05  |
# |    n_updates        | 137      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.53     |
# |    ep_rew_mean      | 6.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1        |
# |    time_elapsed     | 374      |
# |    total_timesteps  | 680      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.26e-05 |
# |    n_updates        | 144      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.48     |
# |    ep_rew_mean      | 6.48     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1        |
# |    time_elapsed     | 394      |
# |    total_timesteps  | 717      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.04e-05 |
# |    n_updates        | 154      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.25     |
# |    ep_rew_mean      | 6.25     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1        |
# |    time_elapsed     | 406      |
# |    total_timesteps  | 744      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.09e-05 |
# |    n_updates        | 160      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.44     |
# |    ep_rew_mean      | 6.44     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1        |
# |    time_elapsed     | 416      |
# |    total_timesteps  | 767      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.6e-05  |
# |    n_updates        | 166      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.93     |
# |    ep_rew_mean      | 5.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1        |
# |    time_elapsed     | 427      |
# |    total_timesteps  | 781      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000159 |
# |    n_updates        | 170      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.93     |
# |    ep_rew_mean      | 5.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1        |
# |    time_elapsed     | 432      |
# |    total_timesteps  | 785      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.76e-05 |
# |    n_updates        | 171      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.65     |
# |    ep_rew_mean      | 5.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1        |
# |    time_elapsed     | 438      |
# |    total_timesteps  | 789      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000208 |
# |    n_updates        | 172      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.94     |
# |    ep_rew_mean      | 4.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1        |
# |    time_elapsed     | 444      |
# |    total_timesteps  | 793      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.62e-05 |
# |    n_updates        | 173      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.67     |
# |    ep_rew_mean      | 4.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1        |
# |    time_elapsed     | 450      |
# |    total_timesteps  | 797      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000662 |
# |    n_updates        | 174      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.2      |
# |    ep_rew_mean      | 4.2      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1        |
# |    time_elapsed     | 455      |
# |    total_timesteps  | 801      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000157 |
# |    n_updates        | 175      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.2      |
# |    ep_rew_mean      | 4.2      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1        |
# |    time_elapsed     | 461      |
# |    total_timesteps  | 805      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.33e-05 |
# |    n_updates        | 176      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94     |
# |    ep_rew_mean      | 3.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1        |
# |    time_elapsed     | 467      |
# |    total_timesteps  | 809      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0009   |
# |    n_updates        | 177      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.01     |
# |    ep_rew_mean      | 3.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1        |
# |    time_elapsed     | 473      |
# |    total_timesteps  | 813      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000188 |
# |    n_updates        | 178      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.01     |
# |    ep_rew_mean      | 3.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1        |
# |    time_elapsed     | 478      |
# |    total_timesteps  | 817      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.43e-05 |
# |    n_updates        | 179      |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [56], in <cell line: 2>()
#       1 # training
# ----> 2 model.learn(total_timesteps=1000, callback=callback)
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\dqn\dqn.py:265, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     255 def learn(
#     256     self: SelfDQN,
#     257     total_timesteps: int,
#    (...)
#     262     progress_bar: bool = False,
#     263 ) -> SelfDQN:
# --> 265     return super().learn(
#     266         total_timesteps=total_timesteps,
#     267         callback=callback,
#     268         log_interval=log_interval,
#     269         tb_log_name=tb_log_name,
#     270         reset_num_timesteps=reset_num_timesteps,
#     271         progress_bar=progress_bar,
#     272     )
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:334, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     331 callback.on_training_start(locals(), globals())
#     333 while self.num_timesteps < total_timesteps:
# --> 334     rollout = self.collect_rollouts(
#     335         self.env,
#     336         train_freq=self.train_freq,
#     337         action_noise=self.action_noise,
#     338         callback=callback,
#     339         learning_starts=self.learning_starts,
#     340         replay_buffer=self.replay_buffer,
#     341         log_interval=log_interval,
#     342     )
#     344     if rollout.continue_training is False:
#     345         break
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:567, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     564 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     566 # Rescale and perform action
# --> 567 new_obs, rewards, dones, infos = env.step(actions)
#     569 self.num_timesteps += env.num_envs
#     570 num_collected_steps += 1
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:163, in VecEnv.step(self, actions)
#     156 """
#     157 Step the environments with the given action
#     158
#     159 :param actions: the action
#     160 :return: observation, reward, done, information
#     161 """
#     162 self.step_async(actions)
# --> 163 return self.step_wait()
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:54, in DummyVecEnv.step_wait(self)
#      52 def step_wait(self) -> VecEnvStepReturn:
#      53     for env_idx in range(self.num_envs):
# ---> 54         obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      55             self.actions[env_idx]
#      56         )
#      57         if self.buf_dones[env_idx]:
#      58             # save final observation where user can get it, then reset
#      59             self.buf_infos[env_idx]["terminal_observation"] = obs
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\common\monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, done, info = self.env.step(action)
#      95 self.rewards.append(reward)
#      96 if done:
#
# Input In [47], in game.step(self, action)
#      21     pydirectinput.press(action_map[action])
#      23 # check for gameover
# ---> 24 done, done_cap = self.get_done()
#      25 # check next observ
#      26 new_observ = self.get_observation()
#
# Input In [47], in game.get_done(self)
#      67 done = False
#      68 # get string
# ---> 69 res = pytesseract.image_to_string(done_cap)[:4]
#      70 if res in done_str:
#      71     # found gameover
#      72     done = True
#
# File ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py:423, in image_to_string(image, lang, config, nice, output_type, timeout)
#     418 """
#     419 Returns the result of a Tesseract OCR run on the provided image to string
#     420 """
#     421 args = [image, 'txt', lang, config, nice, timeout]
# --> 423 return {
#     424     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     425     Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     426     Output.STRING: lambda: run_and_get_output(*args),
#     427 }[output_type]()
#
# File ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py:426, in image_to_string.<locals>.<lambda>()
#     418 """
#     419 Returns the result of a Tesseract OCR run on the provided image to string
#     420 """
#     421 args = [image, 'txt', lang, config, nice, timeout]
#     423 return {
#     424     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     425     Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 426     Output.STRING: lambda: run_and_get_output(*args),
#     427 }[output_type]()
#
# File ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py:288, in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     277 with save(image) as (temp_name, input_filename):
#     278     kwargs = {
#     279         'input_filename': input_filename,
#     280         'output_filename_base': temp_name,
#    (...)
#     285         'timeout': timeout,
#     286     }
# --> 288     run_tesseract(**kwargs)
#     289     filename = f"{kwargs['output_filename_base']}{extsep}{extension}"
#     290     with open(filename, 'rb') as output_file:
#
# File ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py:262, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     259     else:
#     260         raise TesseractNotFoundError()
# --> 262 with timeout_manager(proc, timeout) as error_string:
#     263     if proc.returncode:
#     264         raise TesseractError(proc.returncode, get_errors(error_string))
#
# File ~\anaconda3\lib\contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py:127, in timeout_manager(proc, seconds)
#     125 try:
#     126     if not seconds:
# --> 127         yield proc.communicate()[1]
#     128         return
#     130     try:
#
# File ~\anaconda3\lib\subprocess.py:1134, in Popen.communicate(self, input, timeout)
#    1131     endtime = None
#    1133 try:
# -> 1134     stdout, stderr = self._communicate(input, endtime, timeout)
#    1135 except KeyboardInterrupt:
#    1136     # https://bugs.python.org/issue25942
#    1137     # See the detailed comment in .wait().
#    1138     if timeout is not None:
#
# File ~\anaconda3\lib\subprocess.py:1508, in Popen._communicate(self, input, endtime, orig_timeout)
#    1504 # Wait for the reader threads, or time out.  If we time out, the
#    1505 # threads remain reading and the fds left open in case the user
#    1506 # calls communicate again.
#    1507 if self.stdout is not None:
# -> 1508     self.stdout_thread.join(self._remaining_time(endtime))
#    1509     if self.stdout_thread.is_alive():
#    1510         raise TimeoutExpired(self.args, orig_timeout)
#
# File ~\anaconda3\lib\threading.py:1053, in Thread.join(self, timeout)
#    1050     raise RuntimeError("cannot join current thread")
#    1052 if timeout is None:
# -> 1053     self._wait_for_tstate_lock()
#    1054 else:
#    1055     # the behavior of a negative timeout isn't documented, but
#    1056     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1057     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~\anaconda3\lib\threading.py:1073, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1070     return
#    1072 try:
# -> 1073     if lock.acquire(block, timeout):
#    1074         lock.release()
#    1075         self._stop()
#
# KeyboardInterrupt:

# %%
# test model
for ep in range(5):
    obs = env.reset()
    done = False
    total_reward = 0
    
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(int(action))
        time.sleep(0.01)
        total_reward += reward
    print(f'total reward for ep {ep} is {total_reward}')
#     time.sleep(2)
# Out:
# total reward for ep 0 is 421
# total reward for ep 1 is 10
# total reward for ep 2 is 34
# total reward for ep 3 is 14
# total reward for ep 4 is 12

# %%
# model.load(os.path.join('train_first', 'best_model_900'))
