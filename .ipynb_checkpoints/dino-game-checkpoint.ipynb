# %%
# install pytorch
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116
# show what we got
# !pip list
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# Requirement already satisfied: torch in c:\users\renny\anaconda3\lib\site-packages (1.13.1+cu116)
# Requirement already satisfied: torchvision in c:\users\renny\anaconda3\lib\site-packages (0.14.1+cu116)
# Requirement already satisfied: torchaudio in c:\users\renny\anaconda3\lib\site-packages (0.13.1+cu116)
# Requirement already satisfied: typing-extensions in c:\users\renny\anaconda3\lib\site-packages (from torch) (4.3.0)
# Requirement already satisfied: numpy in c:\users\renny\anaconda3\lib\site-packages (from torchvision) (1.21.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\renny\anaconda3\lib\site-packages (from torchvision) (9.2.0)
# Requirement already satisfied: requests in c:\users\renny\anaconda3\lib\site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\renny\anaconda3\lib\site-packages (from requests->torchvision) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\renny\anaconda3\lib\site-packages (from requests->torchvision) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\renny\anaconda3\lib\site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\renny\anaconda3\lib\site-packages (from requests->torchvision) (3.3)
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.4.0
# alabaster                     0.7.12
# ale-py                        0.7.4
# anaconda-client               1.11.0
# anaconda-navigator            2.3.1
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.11.7
# astropy                       5.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# AutoROM                       0.4.2
# AutoROM.accept-rom-license    0.5.5
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# binaryornot                   0.4.4
# bitarray                      2.5.1
# bkcharts                      0.2
# black                         22.6.0
# bleach                        4.1.0
# bokeh                         2.4.3
# boto3                         1.24.28
# botocore                      1.27.28
# Bottleneck                    1.3.5
# brotlipy                      0.7.0
# cachetools                    5.3.0
# certifi                       2022.9.14
# cffi                          1.15.1
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.0.4
# cloudpickle                   2.0.0
# clyent                        1.2.2
# colorama                      0.4.5
# colorcet                      3.0.0
# comtypes                      1.1.10
# conda                         22.9.0
# conda-build                   3.22.0
# conda-content-trust           0.1.3
# conda-pack                    0.6.0
# conda-package-handling        1.9.0
# conda-repo-cli                1.0.20
# conda-token                   0.4.0
# conda-verify                  3.4.2
# constantly                    15.1.0
# cookiecutter                  1.7.3
# cryptography                  37.0.1
# cssselect                     1.1.0
# cycler                        0.11.0
# Cython                        0.29.32
# cytoolz                       0.11.0
# daal4py                       2021.6.0
# dask                          2022.7.0
# datashader                    0.14.1
# datashape                     0.5.4
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# diff-match-patch              20200713
# dill                          0.3.4
# distributed                   2022.7.0
# docutils                      0.18.1
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# fastjsonschema                2.16.2
# filelock                      3.6.0
# flake8                        4.0.1
# Flask                         1.1.2
# fonttools                     4.25.0
# fsspec                        2022.7.1
# future                        0.18.2
# gensim                        4.1.2
# glob2                         0.7
# google-auth                   2.16.1
# google-auth-oauthlib          0.4.6
# greenlet                      1.1.1
# grpcio                        1.51.3
# gym                           0.21.0
# h5py                          3.7.0
# HeapDict                      1.0.1
# holoviews                     1.15.0
# hvplot                        0.8.0
# hyperlink                     21.0.0
# idna                          3.3
# imagecodecs                   2021.8.26
# imageio                       2.19.3
# imagesize                     1.4.1
# importlib-metadata            4.13.0
# importlib-resources           5.12.0
# incremental                   21.3.0
# inflection                    0.5.1
# iniconfig                     1.1.1
# intake                        0.6.5
# intervaltree                  3.1.0
# ipykernel                     6.15.2
# ipython                       7.31.1
# ipython-genutils              0.2.0
# ipywidgets                    7.6.5
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# itsdangerous                  2.0.1
# jdcal                         1.4.1
# jedi                          0.18.1
# jellyfish                     0.9.0
# Jinja2                        2.11.3
# jinja2-time                   0.2.0
# jmespath                      0.10.0
# joblib                        1.1.0
# json5                         0.9.6
# jsonschema                    4.16.0
# jupyter                       1.0.0
# jupyter_client                7.3.4
# jupyter-console               6.4.3
# jupyter_core                  4.11.1
# jupyter-server                1.18.1
# jupyterlab                    3.4.4
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.10.3
# jupyterlab-widgets            1.0.0
# jupyterthemes                 0.20.0
# keyring                       23.4.0
# kiwisolver                    1.4.2
# lazy-object-proxy             1.6.0
# lesscpy                       0.15.1
# libarchive-c                  2.9
# libtorrent                    2.0.7
# llvmlite                      0.38.0
# locket                        1.0.0
# lxml                          4.9.1
# lz4                           3.1.3
# Markdown                      3.3.4
# markdown-it-py                2.2.0
# MarkupSafe                    2.0.1
# matplotlib                    3.5.2
# matplotlib-inline             0.1.6
# mccabe                        0.6.1
# mdurl                         0.1.2
# menuinst                      1.4.19
# mistune                       0.8.4
# mkl-fft                       1.3.1
# mkl-random                    1.2.2
# mkl-service                   2.4.0
# mock                          4.0.3
# mpmath                        1.2.1
# msgpack                       1.0.3
# mss                           7.0.1
# multipledispatch              0.6.0
# munkres                       1.1.4
# mypy-extensions               0.4.3
# navigator-updater             0.3.0
# nbclassic                     0.3.5
# nbclient                      0.5.13
# nbconvert                     6.4.4
# nbformat                      5.5.0
# nest-asyncio                  1.5.5
# networkx                      2.8.4
# nltk                          3.7
# nose                          1.3.7
# notebook                      6.4.12
# numba                         0.55.1
# numexpr                       2.8.3
# numpy                         1.21.5
# numpydoc                      1.4.0
# oauthlib                      3.2.2
# olefile                       0.46
# opencv-python                 4.7.0.72
# openpyxl                      3.0.10
# packaging                     21.3
# pandas                        1.4.4
# pandocfilters                 1.5.0
# panel                         0.13.1
# param                         1.12.0
# paramiko                      2.8.1
# parsel                        1.6.0
# parso                         0.8.3
# partd                         1.2.0
# pathlib                       1.0.1
# pathspec                      0.9.0
# patsy                         0.5.2
# pep8                          1.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.2.0
# pip                           22.2.2
# pkginfo                       1.8.2
# platformdirs                  2.5.2
# plotly                        5.9.0
# pluggy                        1.0.0
# ply                           3.11
# poyo                          0.5.0
# prometheus-client             0.14.1
# prompt-toolkit                3.0.20
# Protego                       0.1.16
# protobuf                      3.20.3
# psutil                        5.9.0
# ptyprocess                    0.7.0
# py                            1.11.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycodestyle                   2.8.0
# pycosat                       0.6.3
# pycparser                     2.21
# pyct                          0.4.8
# pycurl                        7.45.1
# PyDirectInput                 1.0.4
# PyDispatcher                  2.0.5
# pydocstyle                    6.1.1
# pyerfa                        2.0.0
# pyflakes                      2.4.0
# Pygments                      2.14.0
# PyHamcrest                    2.0.2
# PyJWT                         2.4.0
# pylint                        2.14.5
# pyls-spyder                   0.4.0
# PyNaCl                        1.5.0
# pyodbc                        4.0.34
# pyOpenSSL                     22.0.0
# pyparsing                     3.0.9
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# pytesseract                   0.3.10
# pytest                        7.1.2
# python-dateutil               2.8.2
# python-lsp-black              1.0.0
# python-lsp-jsonrpc            1.0.0
# python-lsp-server             1.3.3
# python-slugify                5.0.2
# python-snappy                 0.6.0
# pytz                          2022.1
# pyviz-comms                   2.0.2
# PyWavelets                    1.3.0
# pywin32                       302
# pywin32-ctypes                0.2.0
# pywinpty                      2.0.2
# PyYAML                        6.0
# pyzmq                         23.2.0
# QDarkStyle                    3.0.2
# qstylizer                     0.1.10
# QtAwesome                     1.0.3
# qtconsole                     5.2.2
# QtPy                          2.2.0
# queuelib                      1.5.0
# regex                         2022.7.9
# requests                      2.28.1
# requests-file                 1.5.1
# requests-oauthlib             1.3.1
# rich                          13.3.1
# rope                          0.22.0
# rsa                           4.9
# Rtree                         0.9.7
# ruamel-yaml-conda             0.15.100
# s3transfer                    0.6.0
# scikit-image                  0.19.2
# scikit-learn                  1.0.2
# scikit-learn-intelex          2021.20221004.171935
# scipy                         1.9.1
# Scrapy                        2.6.2
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# service-identity              18.1.0
# setuptools                    63.4.1
# sip                           4.19.13
# six                           1.16.0
# smart-open                    5.2.1
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# sortedcollections             2.1.0
# sortedcontainers              2.4.0
# soupsieve                     2.3.1
# Sphinx                        5.0.2
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        5.2.2
# spyder-kernels                2.2.1
# SQLAlchemy                    1.4.39
# stable-baselines3             1.7.0
# statsmodels                   0.13.2
# sympy                         1.10.1
# tables                        3.6.1
# tabulate                      0.8.10
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.0.1
# tensorboard                   2.12.0
# tensorboard-data-server       0.7.0
# tensorboard-plugin-wit        1.8.1
# terminado                     0.13.1
# testpath                      0.6.0
# text-unidecode                1.3
# textdistance                  4.2.1
# threadpoolctl                 2.2.0
# three-merge                   0.1.1
# tifffile                      2021.7.2
# tinycss                       0.4
# tldextract                    3.2.0
# toml                          0.10.2
# tomli                         2.0.1
# tomlkit                       0.11.1
# toolz                         0.11.2
# torch                         1.13.1+cu116
# torchaudio                    0.13.1+cu116
# torchvision                   0.14.1+cu116
# tornado                       6.1
# tqdm                          4.64.1
# traitlets                     5.1.1
# Twisted                       22.2.0
# twisted-iocpsupport           1.0.2
# typing_extensions             4.3.0
# ujson                         5.4.0
# Unidecode                     1.2.0
# urllib3                       1.26.11
# w3lib                         1.21.0
# watchdog                      2.1.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.58.0
# Werkzeug                      2.0.3
# wheel                         0.37.1
# widgetsnbextension            3.5.2
# win-inet-pton                 1.1.0
# win-unicode-console           0.5
# wincertstore                  0.2
# wrapt                         1.14.1
# xarray                        0.20.1
# xlrd                          2.0.1
# XlsxWriter                    3.0.3
# xlwings                       0.27.15
# yapf                          0.31.0
# zict                          2.1.0
# zipp                          3.8.0
# zope.interface                5.4.0

# %%
# install stable-baslines (implementations of reinforcement learning algorithms in PyTorch)
# !pip install stable-baselines3[extra] protobuf==3.20.*
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\renny\anaconda3\lib\site-packages (1.7.0)
# Requirement already satisfied: protobuf==3.20.* in c:\users\renny\anaconda3\lib\site-packages (3.20.3)
# Requirement already satisfied: numpy in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.21.5)
# Requirement already satisfied: cloudpickle in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: pandas in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: torch>=1.11 in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.13.1+cu116)
# Requirement already satisfied: gym==0.21 in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: matplotlib in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.5.2)
# Requirement already satisfied: importlib-metadata~=4.13 in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.13.0)
# Requirement already satisfied: tqdm in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.64.1)
# Requirement already satisfied: opencv-python in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.7.0.72)
# Requirement already satisfied: pillow in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (9.2.0)
# Requirement already satisfied: ale-py==0.7.4 in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.7.4)
# Requirement already satisfied: psutil in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.12.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: rich in c:\users\renny\anaconda3\lib\site-packages (from stable-baselines3[extra]) (13.3.1)
# Requirement already satisfied: importlib-resources in c:\users\renny\anaconda3\lib\site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (5.12.0)
# Requirement already satisfied: click in c:\users\renny\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (8.0.4)
# Requirement already satisfied: requests in c:\users\renny\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.28.1)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\renny\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.5.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\renny\anaconda3\lib\site-packages (from importlib-metadata~=4.13->stable-baselines3[extra]) (3.8.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.51.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.16.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.0.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\renny\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (63.4.1)
# Requirement already satisfied: typing-extensions in c:\users\renny\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (4.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\renny\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\renny\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\renny\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\renny\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\renny\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\renny\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\renny\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2022.1)
# Requirement already satisfied: pygments<3.0.0,>=2.14.0 in c:\users\renny\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]) (2.14.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.1.0 in c:\users\renny\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]) (2.2.0)
# Requirement already satisfied: colorama in c:\users\renny\anaconda3\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.5)
# Requirement already satisfied: six>=1.9.0 in c:\users\renny\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\renny\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\renny\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\renny\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\renny\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\renny\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.1.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\renny\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\renny\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\renny\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\renny\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: libtorrent in c:\users\renny\anaconda3\lib\site-packages (from AutoROM.accept-rom-license->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.0.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\renny\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\renny\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)

# %%
# install pydirectinput for input handaling
# !pip install pydirectinput
# Out:
# Requirement already satisfied: pydirectinput in c:\users\renny\anaconda3\lib\site-packages (1.0.4)

# %%
# install pytesseract for OCR
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in c:\users\renny\anaconda3\lib\site-packages (0.3.10)
# Requirement already satisfied: packaging>=21.3 in c:\users\renny\anaconda3\lib\site-packages (from pytesseract) (21.3)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\renny\anaconda3\lib\site-packages (from pytesseract) (9.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\renny\anaconda3\lib\site-packages (from packaging>=21.3->pytesseract) (3.0.9)

# %%
# instal mss for image capture
# !pip install mss
# Out:
# Requirement already satisfied: mss in c:\users\renny\anaconda3\lib\site-packages (7.0.1)

# %%
# screen capture
from mss import mss
# command sending 
import pydirectinput
# fram proccesing
import cv2
# transformatinoal framework
import numpy as np
# OCR for game extraction
import pytesseract
# visualize captures
from matplotlib import pyplot as plt
# pause time
import time
# env componenet
from gym import Env
# box for the image, descrete for possible actions
from gym.spaces import Box, Discrete

# %%
 # set tessoract locations
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
class game(Env):
    # set env action and obser shaps
    def __init__(self):
        # use the base class
        super().__init__()
        # setup spaces
        self.observ_space = Box(low=0, high=255, shape=(1,83,100), dtype=np.uint8)
        self.action_space = Discrete(3)
        # def extraction parameters
        self.cap = mss()
        self.game_location = {'top':300, 'left':500, 'width':400, 'height':400}
        self.done_location = {'top':405, 'left':800, 'width':330, 'height':80}
        
    # called to do somehitng in the game     
    def step(self, action):
        # actions: 0 - space(jump), 1 - down(duck), 2 - no action(no op) 
        action_map = {0: 'space', 1: 'down', 2: 'no_op'}
    
        # simulate press if not no_op
        if action != 2:
            pydirectinput.press(action_map[action])
    
        # check for gameover
        done, done_cap = self.env.get_done()
        # check next observ
        new_observ = self.get_observation()
        # reward - get point for each frame that isn't gameover
        reward = 1
        #info dic
        info = {}
        return new_observ, reward, done, 
    # vusualize the game
    def render(self):
        cv2.imshow('Game', np.array(self.cap.grab(self.game_location))[:,:,:3])
        if cv2.waitKey(1) & 0xFF == ord('q'):
            self.close()
    # closes the done observ
    def close(self):
        cv2.destroyAllWindows()
    # restart the game     
    def reset(self):
        time.sleep(1)
        pydirectinput.click(x=150, y=150)
        pydirectinput.press('space')
        return self.get_observ()

    # get a part of the observation that we want
    def get_observ(self):
        # get screen capture (only first 3 cahnnels) and extract the values from it
        raw = np.array(self.cap.grab(self.game_location))[:,:,:3]
        # grayscale
        gray = cv2.cvtColor(raw, cv2.COLOR_BGR2GRAY)
        # resize
        resized = cv2.resize(gray, (100,83))
        # add channels first 
        channel = np.reshape(resized, (1, 83, 100))
        return channel
    # get the done text with OCR
    def get_done(self):
        # get done screen
        done_cap = np.array(self.cap.grab(self.done_location))[:,:,:3]
        # valid done text
        done_str = ['GAME','GAHE']
        
        # Apply OCR
        # flag to recognize gameover
        done = False
        # get string
        res = pytesseract.image_to_string(done_cap)[:4]
        if res in done_str:
            # found gameover
            done = True
        # return game status
        return done, done_cap

# %%
env = game()

# %%
done, done_cap = env.get_done()

# %%
done
# Out:
# False

# %%
env.render()

# %%
env.close()

# %%
# observ values
env.get_observ()
# Out:
# array([[[ 12,  12,  12, ...,  61,  61,  61],
#         [ 12,  12,  47, ...,  61,  61,  61],
#         [ 12,  12, 141, ...,  61,  61,  61],
#         ...,
#         [ 12,  12,  12, ...,  48,  48,  48],
#         [187,  12,  12, ...,  48,  48,  48],
#         [101,  12,  75, ...,  48,  48, 177]]], dtype=uint8)

# %%
# observ after proccecing
plt.imshow(env.get_observ()[0])

# %%
# observ after proccecing it back to the original
plt.imshow(cv2.cvtColor(env.get_observ()[0], cv2.COLOR_BGR2RGB))
